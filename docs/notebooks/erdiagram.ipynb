# %%
from eralchemy2 import render_er
from biokb_wfo.db.models import Base
import os

# %% [markdown]
# # Entity-relationship diagram

# %% [markdown]
# This notebook is used to generate an entity-relationship diagram from the SQLAlchemy models defined in the `biokb_wfo` package.

# %%
# ensure the output directory exists, then render the ER diagram to PNG
os.makedirs(os.path.join("..", "imgs"), exist_ok=True)
render_er(Base, os.path.join("..", "imgs", "erd_from_sqlalchemy.png"))

# %% [markdown]
# ![ER model](https://raw.githubusercontent.com/biokb/biokb_wfo/refs/heads/main/docs/imgs/erd_from_sqlalchemy.png)

# %% [markdown]
# ![](../assets/biokb_logo.png)
