# %%
from biokb_wfo import DbManager, TurtleCreator, Neo4jImporter
import os
from dotenv import load_dotenv
import os

# %%
load_dotenv(os.path.join("..", ".env_local"), override=True)

# %% [markdown]
# # Test the workflow with default settings
#
# Default settings import the data into `~/.biokb/biokb.db`

# %%
DbManager().import_data()
# TurtleCreator().create_ttls()

# %% [markdown]
# Before starting the import into neo4j start a test container with:
# ```bash
# podman run --rm --name biokb-neo4j-test -p7474:7474 -p7687:7687 -e NEO4J_AUTH=neo4j/neo4j_password neo4j:5.26.14
# ```

# %%
# Neo4jImporter().import_ttls()

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password
